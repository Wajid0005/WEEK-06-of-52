# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/reeno005/house-data/Scraped_Data.csv

# %%
OG_Data = pd.read_csv("/kaggle/input/datasets/reeno005/house-data/Scraped_Data.csv")
OG_Data.sample(10)
# Out:
#        exactPrice  sqftPrice  securityDeposit             propertyType  \
# 10857       25000         20            20000    Multistorey Apartment
# 7159         6500         11                9        Residential House
# 20261     6500000       5909                9    Multistorey Apartment
# 5995        13000         16                9  Builder Floor Apartment
# 26081    19000000       2381                9        Residential House
# 1916        15000         14            45000    Multistorey Apartment
# 26715     4200000       2897                9        Residential House
# 500          4000          4                9        Residential House
# 9348         8500         14                9    Multistorey Apartment
# 22403     5500000       3793                9  Builder Floor Apartment
#
#           postedOn  noOfLifts maintenanceChargesFrequency  maintenanceCharges  \
# 10857  Jun 30, '23        9.0                     Monthly                2000
# ...

# %%
OG_Data.describe()
# Out:
#          exactPrice     sqftPrice  securityDeposit     noOfLifts  \
# count  2.790000e+04  2.790000e+04     2.790000e+04  27445.000000
# mean   5.427532e+06  4.293275e+04     2.407937e+04      7.870978
# std    2.699586e+07  2.264502e+06     1.074923e+05      2.602134
# min    9.000000e+00  0.000000e+00     1.000000e+00      1.000000
# 25%    1.300000e+04  1.100000e+01     9.000000e+00      9.000000
# 50%    3.000000e+04  2.100000e+01     9.000000e+00      9.000000
# 75%    5.269500e+06  3.864250e+03     1.400000e+04      9.000000
# max    3.250000e+09  2.000000e+08     5.000000e+06     10.000000
#
#        maintenanceCharges  firstMonthCharges   totalFlrNum    carpetArea  \
# count        2.790000e+04       2.790000e+04  27900.000000  27900.000000
# mean         2.902351e+05       3.327781e+05      5.665520    609.963584
# std          4.835278e+07       4.835763e+07      7.012247    837.434426
# min          0.000000e+00       9.000000e+00      1.000000      1.000000
# ...

# %% [markdown]
# **We need to drop some of the columns that are not in use**
#
# **First we need to make the copy of the data so the Real data doesn't get hamper!**

# %%
data = OG_Data.copy()
data.sample(1)
# Out:
#        exactPrice  sqftPrice  securityDeposit       propertyType     postedOn  \
# 25749     6500000       5000                9  Residential House  Mar 16, '23
#
#        noOfLifts maintenanceChargesFrequency  maintenanceCharges  locality  \
# 25749        9.0                           9                   9  IIM Road
#
#            furnishing  ... Cafeteria_Or_Food_Court  CCTV_Camera Barbeque_Pit  \
# 25749  Semi-Furnished  ...                       9            9            9
#
#        Bar_Or_Lounge Banquet_Hall Bank__And__ATM  Arts__And__Craft_Studio  \
# 25749              9            9              9                        9
#
#       Air_Conditioned  Activity_Deck4  AEROBICS_ROOM
# 25749               9               9              9
#
# [1 rows x 91 columns]

# %%
data.rename(columns = {'noOfLifts':'no_of_lifts'}, inplace=True)
data
# Out:
#        exactPrice  sqftPrice  securityDeposit           propertyType  \
# 0          240000        171                9  Multistorey Apartment
# 1           12000         12            12000  Multistorey Apartment
# 2           17000          7                9      Residential House
# 3            5000          9                9      Residential House
# 4           12000          9            24000  Multistorey Apartment
# ...           ...        ...              ...                    ...
# 27895    20227500       7500                9  Multistorey Apartment
# 27896     6933500       4900                9  Multistorey Apartment
# 27897     9000000       8182                9                  Villa
# 27898     7645000       5500                9  Multistorey Apartment
# 27899    11525400       5700                9  Multistorey Apartment
#
#           postedOn  no_of_lifts maintenanceChargesFrequency  \
# 0      Jun 20, '23          9.0                           9
# ...

# %%
data['furnishing'].unique()
# Out:
# array(['Semi-Furnished', 'Furnished', 'Unfurnished', '9'], dtype=object)

# %%
data['locality'].unique()
# Out:
# array(['Danapur', '9', 'Phase 1 Ashiana Nagar', ..., 'Curzon Road',
#        'Malhour', 'Prakash Lok Colony'], dtype=object)

# %%
data['maintenanceChargesFrequency'].unique()
# Out:
# array(['9', 'Monthly', 'Quarterly', 'Yearly', 'One-Time',
#        'Per sq. Unit Monthly'], dtype=object)

# %%
data['maintenanceCharges'].unique()
# Out:
# array([         9,       1500,        500,       2000,       1000,
#               200,        100,      17000,      27000,       5000,
#              3500,       1200,       4000,       2500,        300,
#              1400,       3000,       1700,       2400,       1600,
#              1300,       1800,        350,        800,        150,
#              1100,      10000,          1,       1735,       1840,
#             28000,      25000,      12000,        750,       2450,
#               900,        250,        700,      10004,       2100,
#               166,         20,       1250,       2200,        120,
#              3300,      15000,       6000,       3250,        400,
#              2300,       7000,         50,      43000,      19000,
#                30,         41,       2800,       1111,        600,
#               416,         80,      20000,          0,       5100,
#              1666,        650,       3400,         83,       4800,
# ...
